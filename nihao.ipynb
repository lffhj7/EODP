# %%
import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns

import nltkl
from nltk.corpus import stopwords

from sklearn.feature_selection import mutual_info_classif
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       3 from matplotlib import pyplot as plt
#       4 import seaborn as sns
# ----> 6 import nltkl
#       7 from nltk.corpus import stopwords
#       9 from sklearn.feature_selection import mutual_info_classif
#
# ModuleNotFoundError: No module named 'nltkl'

# %%
titles = pd.read_csv("titles-dropped.csv")
titles.head(100)
# Out:
#           id                            title   type  \
# 0    tm84618                      Taxi Driver  MOVIE
# 1   tm154986                      Deliverance  MOVIE
# 2   tm127384  Monty Python and the Holy Grail  MOVIE
# 3   tm120801                  The Dirty Dozen  MOVIE
# 4    ts22164     Monty Python's Flying Circus   SHOW
# ..       ...                              ...    ...
# 95  tm191110                          Titanic  MOVIE
# 96   ts34435                     Cowboy Bebop   SHOW
# 97  tm192037                Starship Troopers  MOVIE
# 98   tm27395           Mission: Impossible II  MOVIE
# 99  tm113513                  Dumb and Dumber  MOVIE
#
#                                           description  release_year  \
# 0   A mentally unstable Vietnam War veteran works ...          1976
# 1   Intent on seeing the Cahulawassee River before...          1972
# 2   King Arthur, accompanied by his squire, recrui...          1975
# 3   12 American military prisoners in World War II...          1967
# 4   A British sketch comedy series with the shows ...          1969
# ..                                                ...           ...
# 95  101-year-old Rose DeWitt Bukater tells the sto...          1997
# 96  In 2071, roughly fifty years after an accident...          1998
# 97  Set in the future, the story follows a young s...          1997
# 98  With computer genius Luther Stickell at his si...          2000
# 99  Lloyd and Harry are two men whose stupidity is...          1994
#
#    age_certification  runtime  \
# 0                  R      114
# 1                  R      109
# 2                 PG       91
# 3                NaN      150
# 4              TV-14       30
# ..               ...      ...
# 95             PG-13      194
# 96             TV-14       25
# 97                 R      129
# 98             PG-13      123
# 99             PG-13      107
#
#                                                genres production_countries  \
# 0                                  ['drama', 'crime']               ['US']
# 1         ['drama', 'action', 'thriller', 'european']               ['US']
# 2                     ['fantasy', 'action', 'comedy']               ['GB']
# 3                                   ['war', 'action']         ['GB', 'US']
# 4                              ['comedy', 'european']               ['GB']
# ..                                                ...                  ...
# 95                               ['drama', 'romance']               ['US']
# 96  ['animation', 'action', 'scifi', 'western', 'c...               ['JP']
# 97                    ['scifi', 'action', 'thriller']               ['US']
# 98                             ['thriller', 'action']               ['US']
# 99                                         ['comedy']               ['US']
#
#     seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0       NaN  tt0075314         8.2    808582.0           40.965       8.179
# 1       NaN  tt0068473         7.7    107673.0           10.010       7.300
# 2       NaN  tt0071853         8.2    534486.0           15.461       7.811
# 3       NaN  tt0061578         7.7     72662.0           20.398       7.600
# 4       4.0  tt0063929         8.8     73424.0           17.617       8.306
# ..      ...        ...         ...         ...              ...         ...
# 95      NaN  tt0120338         7.9   1146825.0          155.683       7.878
# 96      1.0  tt0213338         8.9    115448.0           35.402       8.522
# 97      NaN  tt0120201         7.3    291452.0           29.500       6.993
# 98      NaN  tt0120755         6.1    337987.0           29.392       6.100
# 99      NaN  tt0109686         7.3    379999.0           31.852       6.600
#
# [100 rows x 15 columns]

# %% [markdown]
# Feature Filtering based on Mutual Information for classification and numerical models
# Set up X-variable:"age_certification", "runtime", "genres", "production_countries"
# with respect Y-variable: "imdb_score", "imdb_votes", "tmdb_popularity", "tmdb_score".

# %%
THRESHOLD = 0.2

X = titles[["age_certification", "genres", "production_countries"]]
Y_imdb_score = titles["imdb_score"]
Y_imdb_votes = titles["imdb_votes"]
Y_tmdb_popularity = titles["tmdb_popularity"]
Y_tmdb_score = titles["tmdb_score"]

mi_arr = mutual_info_classif(X=X, y=Y_imdb_score, discrete_features=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 9
#       6 Y_tmdb_popularity = titles["tmdb_popularity"]
#       7 Y_tmdb_score = titles["tmdb_score"]
# ----> 9 mi_arr = mutual_info_classif(X=X, y=Y_imdb_score, discrete_features=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/feature_selection/_mutual_info.py:492, in mutual_info_classif(X, y, discrete_features, n_neighbors, copy, random_state)
#     405 @validate_params(
#     406     {
#     407         "X": ["array-like", "sparse matrix"],
#    (...)
#     417     X, y, *, discrete_features="auto", n_neighbors=3, copy=True, random_state=None
#     418 ):
#     419     """Estimate mutual information for a discrete target variable.
#     420
#     421     Mutual information (MI) [1]_ between two random variables is a non-negative
#    (...)
#     490            of a Random Vector:, Probl. Peredachi Inf., 23:2 (1987), 9-16
#     491     """
# --> 492     check_classification_targets(y)
#     493     return _estimate_mi(X, y, discrete_features, True, n_neighbors, copy, random_state)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/utils/multiclass.py:215, in check_classification_targets(y)
#     207 y_type = type_of_target(y, input_name="y")
#     208 if y_type not in [
#     209     "binary",
#     210     "multiclass",
#    (...)
#     213     "multilabel-sequences",
#     214 ]:
# --> 215     raise ValueError(
#     216         f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     217         "classifier, which expects discrete classes on a "
#     218         "regression target with continuous values."
#     219     )
#
# ValueError: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.
